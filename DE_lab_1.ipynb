# %% [markdown]
# <a href="https://colab.research.google.com/github/Prabhjotbh/DE_lab_2024/blob/main/DE_lab_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Generation_data.csv")

# %%
df
# Out:
#        MODULE_TEMP  Amb_Temp  WIND_Speed   IRR (W/m2)  DC Current in Amps  \
# 0          18.7675  17.85190    47.60506     6.388252            0.600000
# 1          18.6150  18.59573    64.26684    12.776500            0.660000
# 2          18.9200  18.59573    85.68912    17.035340            4.740000
# 3          18.9200  18.59573    83.30886    25.553010            8.180000
# 4          19.0725  18.59573    57.12608    36.200090           26.660000
# ...            ...       ...         ...          ...                 ...
# 48228      25.6300  19.33956   242.78580   291.730200          245.840000
# 48229      27.3075  20.08339   268.96860   229.977100          197.540000
# 48230      30.8150  20.08339   278.48960  1064.709000          829.379984
# 48231      41.0325  21.57104   278.48960   926.296400          815.939992
# 48232      44.2350  21.57100         NaN          NaN                 NaN
#
#        AC Ir in Amps  AC Iy in Amps  AC Ib in Amps  AC Power in Watts
# ...

# %%
df.head()
# Out:
#    MODULE_TEMP  Amb_Temp  WIND_Speed  IRR (W/m2)  DC Current in Amps  \
# 0      18.7675  17.85190    47.60506    6.388252                0.60
# 1      18.6150  18.59573    64.26684   12.776500                0.66
# 2      18.9200  18.59573    85.68912   17.035340                4.74
# 3      18.9200  18.59573    83.30886   25.553010                8.18
# 4      19.0725  18.59573    57.12608   36.200090               26.66
#
#    AC Ir in Amps  AC Iy in Amps  AC Ib in Amps  AC Power in Watts
# 0            8.6            8.6            8.7               3233
# 1            9.6            9.7           10.0               4504
# 2           11.9           12.0           12.4               6614
# 3           14.8           14.7           14.7               8971
# 4           18.6           18.4           18.5              12071

# %%
df.tail(7)
# Out:
#        MODULE_TEMP  Amb_Temp  WIND_Speed  IRR (W/m2)  DC Current in Amps  \
# 48226     27.15499  20.08339    283.2501    195.9064          170.220000
# 48227     24.41000  20.08339    192.8005    168.2240          142.260000
# 48228     25.63000  19.33956    242.7858    291.7302          245.840000
# 48229     27.30750  20.08339    268.9686    229.9771          197.540000
# 48230     30.81500  20.08339    278.4896   1064.7090          829.379984
# 48231     41.03250  21.57104    278.4896    926.2964          815.939992
# 48232     44.23500  21.57100         NaN         NaN                 NaN
#
#        AC Ir in Amps  AC Iy in Amps  AC Ib in Amps  AC Power in Watts
# 48226           87.8           87.8           87.6            65243.0
# 48227           73.2           73.2           73.2            54316.0
# 48228          126.4          126.5          126.5            94803.0
# 48229          101.2          101.1          101.0            75648.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48233 entries, 0 to 48232
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   MODULE_TEMP         48233 non-null  float64
#  1   Amb_Temp            48233 non-null  float64
#  2   WIND_Speed          48232 non-null  float64
#  3   IRR (W/m2)          48232 non-null  float64
#  4   DC Current in Amps  48232 non-null  float64
#  5   AC Ir in Amps       48232 non-null  float64
#  6   AC Iy in Amps       48232 non-null  float64
#  7   AC Ib in Amps       48232 non-null  float64
#  8   AC Power in Watts   48232 non-null  float64
# dtypes: float64(9)
# memory usage: 3.3 MB

# %%
df.describe()
# Out:
#         MODULE_TEMP      Amb_Temp    WIND_Speed    IRR (W/m2)  \
# count  48233.000000  48233.000000  48232.000000  48232.000000
# mean      35.763965     22.172286    393.993385    387.722906
# std       12.023496      3.748074    199.314179    302.999155
# min       10.075000     10.413610      2.380253      2.129417
# 25%       25.172500     19.339560    254.687100    127.765000
# 50%       34.322490     21.571040    418.924600    313.024300
# 75%       45.149990     24.546360    587.922500    609.013300
# max       70.770000     33.472310    597.443500   1441.615000
#
#        DC Current in Amps  AC Ir in Amps  AC Iy in Amps  AC Ib in Amps  \
# count        48232.000000   48232.000000   48232.000000   48232.000000
# mean           327.876657     160.509089     160.361183     160.515011
# std            255.648866     117.441619     117.389924     117.436606
# min              0.600000       2.500000       2.400000       2.500000
# ...

# %%
df.dtypes
# Out:
# MODULE_TEMP           float64
# Amb_Temp              float64
# WIND_Speed            float64
# IRR (W/m2)            float64
# DC Current in Amps    float64
# AC Ir in Amps         float64
# AC Iy in Amps         float64
# AC Ib in Amps         float64
# AC Power in Watts     float64
# dtype: object

# %%
df.size
# Out:
# 434097

# %%
df.shape
# Out:
# (48233, 9)

# %%
df.ndim
# Out:
# 2

# %%
df.isnull()
# Out:
#         MODULE_TEMP  Amb_Temp  WIND_Speed  IRR (W/m2)  DC Current in Amps  \
# 0             False     False       False       False               False
# 1             False     False       False       False               False
# 2             False     False       False       False               False
# 3             False     False       False       False               False
# 4             False     False       False       False               False
# ...             ...       ...         ...         ...                 ...
# 118860        False     False       False       False               False
# 118861        False     False       False       False               False
# 118862        False     False       False       False               False
# 118863        False     False       False       False               False
# 118864        False     False       False       False               False
#
#         AC Ir in Amps  AC Iy in Amps  AC Ib in Amps  AC Power in Watts
# ...

# %%
df.isnull().sum()
# Out:
# MODULE_TEMP           0
# Amb_Temp              0
# WIND_Speed            1
# IRR (W/m2)            1
# DC Current in Amps    1
# AC Ir in Amps         1
# AC Iy in Amps         1
# AC Ib in Amps         1
# AC Power in Watts     1
# dtype: int64

# %%
print(df.mean())
# Out:
# MODULE_TEMP               37.141972
# Amb_Temp                  22.961983
# WIND_Speed               224.429052
# IRR (W/m2)               428.093276
# DC Current in Amps       355.902071
# AC Ir in Amps            172.329754
# AC Iy in Amps            172.190557
# AC Ib in Amps            172.351243
# AC Power in Watts     128081.179666
# dtype: float64

# %%
print((df.isnull()).count())
# Out:
# MODULE_TEMP           118865
# Amb_Temp              118865
# WIND_Speed            118865
# IRR (W/m2)            118865
# DC Current in Amps    118865
# AC Ir in Amps         118865
# AC Iy in Amps         118865
# AC Ib in Amps         118865
# AC Power in Watts     118865
# dtype: int64

# %%
df.notna()
# Out:
#         MODULE_TEMP  Amb_Temp  WIND_Speed  IRR (W/m2)  DC Current in Amps  \
# 0              True      True        True        True                True
# 1              True      True        True        True                True
# 2              True      True        True        True                True
# 3              True      True        True        True                True
# 4              True      True        True        True                True
# ...             ...       ...         ...         ...                 ...
# 118860         True      True        True        True                True
# 118861         True      True        True        True                True
# 118862         True      True        True        True                True
# 118863         True      True        True        True                True
# 118864         True      True        True        True                True
#
#         AC Ir in Amps  AC Iy in Amps  AC Ib in Amps  AC Power in Watts
# ...

# %%
df.median()
# Out:
# MODULE_TEMP              34.32249
# Amb_Temp                 21.57104
# WIND_Speed              418.92460
# IRR (W/m2)              313.02430
# DC Current in Amps      267.14000
# AC Ir in Amps           135.60000
# AC Iy in Amps           135.50000
# AC Ib in Amps           135.60000
# AC Power in Watts     99572.50000
# dtype: float64

# %%
mean=df["WIND_Speed"].mean()
mean
# Out:
# 393.99338508398984

# %%
df["WIND_Speed"].fillna(mean,inplace=True)

# %%
df["WIND_Speed"]
# Out:
# 0         47.605060
# 1         64.266840
# 2         85.689120
# 3         83.308860
# 4         57.126080
#             ...
# 48228    242.785800
# 48229    268.968600
# 48230    278.489600
# 48231    278.489600
# 48232    393.993385
# Name: WIND_Speed, Length: 48233, dtype: float64
